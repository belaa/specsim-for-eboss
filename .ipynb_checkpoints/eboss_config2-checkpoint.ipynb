# %% [markdown]
# ## Generate camera data files for instrument configuration

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import bossdata
import fitsio
import os
import specsim
import astropy.units as u
import scipy.constants


from astropy.io import fits
from astropy.table import Table, Column, vstack

# %% [markdown]
# ## Define methods

# %%
fwhm = np.sqrt(8*np.log(2))

def get_hdulist(sequence_number, band, fiber, plan_path):
    
    local_plan_path = mirror.get(plan_path)
    Plan = bossdata.plate.Plan(local_plan_path)
    exp_name = Plan.get_exposure_name(sequence_number=sequence_number, band=band, fiber=fiber, ftype='spCFrame')
    spec_index = Plan.get_spectrograph_index(fiber=fiber)
    local_fits = mirror.get(os.path.join(plan_path.strip(os.path.basename(plan_path)), exp_name))
    hdulist = fits.open(local_fits)
    return(hdulist)

def get_columns(plate, mjd, sequence_number=1):
    
    plan_path = finder.get_plate_plan_path(plate=plate, mjd=mjd, combined=True)
    b1_hdulist = get_hdulist(sequence_number=sequence_number, band='blue', fiber=30, plan_path=plan_path)
    b2_hdulist = get_hdulist(sequence_number=sequence_number, band='blue', fiber=600, plan_path=plan_path)
    r1_hdulist = get_hdulist(sequence_number=sequence_number, band='red', fiber=30, plan_path=plan_path)
    r2_hdulist = get_hdulist(sequence_number=sequence_number, band='red', fiber=600, plan_path=plan_path)
        
    return b1_hdulist, b2_hdulist, r1_hdulist, r2_hdulist

def get_neff(plate, mjd, fiber):
    
    remote_plate_spec_path = finder.get_plate_spec_path(plate=plate, mjd=mjd)
    plate_spec_path = mirror.get(remote_plate_spec_path)
    PlateFile = bossdata.plate.PlateFile(plate_spec_path)    
    
    exp_nameb1 = PlateFile.exposures.get_exposure_name(exposure_index=1, camera='b1', 
                                                     ftype='spFlat')
    exp_nameb2 = PlateFile.exposures.get_exposure_name(exposure_index=1, camera='b2', 
                                                     ftype='spFlat')
    exp_namer1 = PlateFile.exposures.get_exposure_name(exposure_index=1, camera='r1', 
                                                     ftype='spFlat')
    exp_namer2 = PlateFile.exposures.get_exposure_name(exposure_index=1, camera='r2', 
                                                     ftype='spFlat')

    remote_plate_path_b1 = finder.get_plate_path(plate=plate, filename=exp_nameb1)
    remote_plate_path_b2 = finder.get_plate_path(plate=plate, filename=exp_nameb2)
    remote_plate_path_r1 = finder.get_plate_path(plate=plate, filename=exp_namer1)
    remote_plate_path_r2 = finder.get_plate_path(plate=plate, filename=exp_namer2)
    
    plate_path_b1 = mirror.get(remote_plate_path_b1)
    plate_path_b2 = mirror.get(remote_plate_path_b2)
    plate_path_r1 = mirror.get(remote_plate_path_r1)
    plate_path_r2 = mirror.get(remote_plate_path_r2)

    hdulist_b1 = fitsio.FITS(plate_path_b1, mode=fitsio.READONLY)
    hdulist_b2 = fitsio.FITS(plate_path_b2, mode=fitsio.READONLY)
    hdulist_r1 = fitsio.FITS(plate_path_r1, mode=fitsio.READONLY)
    hdulist_r2 = fitsio.FITS(plate_path_r2, mode=fitsio.READONLY)
    
    TraceSet_b1 = bossdata.plate.TraceSet(hdulist_b1[3])
    TraceSet_b2 = bossdata.plate.TraceSet(hdulist_b2[3])
    TraceSet_r1 = bossdata.plate.TraceSet(hdulist_r1[3])
    TraceSet_r2 = bossdata.plate.TraceSet(hdulist_r2[3])

    return TraceSet_b1, TraceSet_b2, TraceSet_r1, TraceSet_r2

def combine(plate, mjd, fwhm=True):
    
    plate_mjd = zip(plate,mjd)
    
    b1neff = np.empty((len(plate_mjd), 500, 4112), dtype=float)
    b2neff = np.empty((len(plate_mjd), 500, 4112), dtype=float)
    r1neff = np.empty((len(plate_mjd), 500, 4128), dtype=float)
    r2neff = np.empty((len(plate_mjd), 500, 4128), dtype=float)        

    b1wlen = np.empty((len(plate_mjd), 500, 4128), dtype=float)
    b2wlen = np.empty((len(plate_mjd), 500, 4128), dtype=float)
    r1wlen = np.empty((len(plate_mjd), 500, 4128), dtype=float)
    r2wlen = np.empty((len(plate_mjd), 500, 4128), dtype=float)

    b1res = np.empty((len(plate_mjd), 500, 4128), dtype=float)
    b2res = np.empty((len(plate_mjd), 500, 4128), dtype=float)
    r1res = np.empty((len(plate_mjd), 500, 4128), dtype=float)
    r2res = np.empty((len(plate_mjd), 500, 4128), dtype=float)

    b1width = np.empty((len(plate_mjd), 500, 4128), dtype=float)
    b2width = np.empty((len(plate_mjd), 500, 4128), dtype=float)
    r1width = np.empty((len(plate_mjd), 500, 4128), dtype=float)
    r2width = np.empty((len(plate_mjd), 500, 4128), dtype=float)
        
    
    
    for i, pair in enumerate(plate_mjd):
        
            
        b1TraceSet, b2TraceSet, r1TraceSet, r2TraceSet = get_neff(plate=pair[0], mjd=pair[1], fiber=0)

        b1neff[i] = b1TraceSet.get_y()
        b2neff[i] = b2TraceSet.get_y()
        r1neff[i] = r1TraceSet.get_y()
        r2neff[i] = r2TraceSet.get_y()
        
        
            
        b1, b2, r1, r2 = get_columns(plate=pair[0], mjd=pair[1], sequence_number=0)
        
        b1wlen[i] = 10**b1[3].data
        b2wlen[i] = 10**b2[3].data
        r1wlen[i] = 10**r1[3].data
        r2wlen[i] = 10**r2[3].data
            

        
        b1width[i] = np.gradient(b1wlen[i], axis=1)
        b2width[i] = np.gradient(b2wlen[i], axis=1)
        r1width[i] = np.gradient(r1wlen[i], axis=1)
        r2width[i] = np.gradient(r2wlen[i], axis=1)

                
        b1res[i] = b1[4].data*0.0001*np.log(10)*b1wlen[i]
        b2res[i] = b2[4].data*0.0001*np.log(10)*b2wlen[i]
        r1res[i] = r1[4].data*0.0001*np.log(10)*r1wlen[i]
        r2res[i] = r2[4].data*0.0001*np.log(10)*r2wlen[i]
                
        if fwhm:
        
            b1res[i] = b1res[i]*fwhm
            b2res[i] = b2res[i]*fwhm
            r1res[i] = r1res[i]*fwhm
            r2res[i] = r2res[i]*fwhm
    
    coef = 2*np.sqrt(np.pi)
                
                
    return(b1wlen, b2wlen, r1wlen, r2wlen, b1res, b2res, r1res, r2res, 
           b1width, b2width, r1width, r2width, coef*b1neff, coef*b2neff, coef*r1neff, coef*r2neff)


def canon_grid(bwlen, rwlen, n_out, lo_trim=None, hi_trim=None):
    
    b_out = np.linspace(np.max(bwlen[:,:,0]), np.min(bwlen[:,:,-1]), n_out)
    r_out = np.linspace(np.max(rwlen[:,:,0]), np.min(rwlen[:,:,-1]), n_out)
    
    if lo_trim:
        b_out = b_out[lo_trim:]
        r_out = r_out[lo_trim:]
        
    if hi_trim:
        b_out = b_out[:hi_trim]
        r_out = r_out[:hi_trim]
    
    return(b_out, r_out)
    
def summarize(bwlen, rwlen, y_b, y_r, b_out, r_out, summary=np.median):
    
    assert bwlen.shape == y_b.shape
    assert rwlen.shape == y_r.shape
    
    n_out = len(b_out)
        
    b_interp = np.empty((20, 1000, n_out), dtype=float)
    r_interp = np.empty((20, 1000, n_out), dtype=float)
    
    for plate in range(20):
        for fiber in range(1000):
            b_interp[plate, fiber] = np.interp(x=b_out, xp=bwlen[plate][fiber], fp=y_b[plate][fiber])
            r_interp[plate, fiber] = np.interp(x=r_out, xp=rwlen[plate][fiber], fp=y_r[plate][fiber])
    
    return(summary(b_interp, axis=(0,1)), summary(r_interp, axis=(0,1)))

# %% [markdown]
# ## Calculate values

# %%
finder = bossdata.path.Finder()
mirror = bossdata.remote.Manager()

plates = [7027, 6963, 7301, 6759, 6002, 6178, 6626, 6882, 7389, 7453, 7517, 7276, 6390, 6472, 6660, 6877, 6970, 
          7451, 6122, 6261]
mjds =  [56448, 56724, 56746, 56416, 56104, 56213, 56330, 56541, 56769, 56749, 56772, 57061, 56244, 56362, 56370, 
         56544, 56444, 56739, 56246, 56219]

n_out = 4128

# %%
b1wlen, b2wlen, r1wlen, r2wlen, b1res, b2res, r1res, r2res, b1width, b2width, r1width, r2width, b1neff, b2neff, r1neff, r2neff = combine(plates, mjds, fwhm=True)

# %%
bwlen = np.concatenate((b1wlen, b2wlen), axis=1)
rwlen = np.concatenate((r1wlen, r2wlen), axis=1)
bres = np.concatenate((b1res, b2res), axis=1)
rres = np.concatenate((r1res, r2res), axis=1)
bwidth = np.concatenate((b1width, b2width), axis=1)
rwidth = np.concatenate((r1width, r2width), axis=1)
bneff = np.concatenate((b1neff, b2neff), axis=1)
rneff = np.concatenate((r1neff, r2neff), axis=1)

# %%
n_out = bneff.shape[2]
b_out, r_out = canon_grid(bwlen, rwlen, n_out, 60, -80) # blue side flats are length 4112, all others are 4128
bres_int, rres_int = summarize(bwlen, rwlen, bres, rres, b_out, r_out)
bwid_int, rwid_int = summarize(bwlen, rwlen, bwidth, rwidth, b_out, r_out)
bnef_int, rnef_int = summarize(bwlen[:,:,:n_out], rwlen, bneff, rneff, b_out, r_out)

# %% [markdown]
# ## DESI configuration

# %%
desi_hdulist = fitsio.FITS('psf-quicksim.fits', mode=fitsio.READONLY)

quicksim_b, quicksim_r, quicksim_z = desi_hdulist[1].read(), desi_hdulist[2].read(), desi_hdulist[3].read()

desi_bwlen = quicksim_b['wavelength']
desi_rwlen = quicksim_r['wavelength']
desi_zwlen = quicksim_z['wavelength']

desi_bres = quicksim_b['fwhm_spatial']
desi_rres = quicksim_r['fwhm_spatial']
desi_zres = quicksim_z['fwhm_spatial']

desi_bwidth = quicksim_b['angstroms_per_row']
desi_rwidth = quicksim_r['angstroms_per_row']
desi_zwidth = quicksim_z['angstroms_per_row']

desi_bneff = quicksim_b['fwhm_wave']
desi_rneff = quicksim_r['fwhm_wave']
desi_zneff = quicksim_z['fwhm_wave']

# %%
plates[0], mjds[0]
# Out:
# (7027, 56448)

# %%
def plot_wlen(wlen_sol, plate, xmin=None, xmax=None, ymin=None, ymax=None, title=None, save=None):
    plt.figure(figsize=(7,5))
    for i in range(wlen_sol.shape[1]):
        plt.plot(wlen_sol[plate][i], '.')
    if xlim:
        plt.xlim(xmin,xmax)
    if ylim:
        plt.ylim(ymin,ymax)
    if title:
        plt.title(title, fontsize=16)
    plt.xlabel('Pixel', fontsize=14)
    plt.ylabel('Wavelength [Angstrom]', fontsize=14)
    if save:
        plt.savefig(save)
    plt.show()

# %%
plot_wlen(b1wlen, 0, 275, 400, 3035, 3200, 'b1', 'b1-sol.png')

# %%
plot_wlen(b2wlen, 0, 250, 350, 3100, 3250, 'b2', 'b2-sol.png')

# %%
plot_wlen(r1wlen, 0, 1000, 1100, 6450, 6700, 'r1', 'r1-sol.png')

# %%
plot_wlen(r2wlen, 0, 1000, 1100, 6450, 6700, 'r2', 'r2-sol.png')

# %%
np.max(desi_zwlen), np.min(desi_bwlen)
np.max(r_out), np.min(b_out)
# Out:
# (10871.973225181586, 3010.8504874186892)

# %%
plt.figure(figsize=(16,10))
plt.plot(np.arange(0,len(desi_bwlen)), desi_bwlen, '--b', lw=4, label='DESI b')
plt.plot(np.arange(0,len(desi_rwlen)), desi_rwlen, '--r', lw=4, label='DESI r')
plt.plot(np.arange(0,len(desi_zwlen)), desi_zwlen, '--k', lw=4, label='DESI z')
plt.plot(b_out, 'b', label='eBOSS b', lw=4)
plt.plot(r_out, 'r', label='eBOSS r', lw=4)
plt.xlabel('Pixel', fontsize=18)
plt.ylabel('Wavelength [Angstrom]', fontsize=18)
#plt.title('20 plates', fontsize=28)
plt.xlim(0,4850)
plt.legend(loc=2, fontsize=18)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.savefig('wavelength_solution.png')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,6))

ax1.plot(b_out, bwid_int, 'b')
ax2.plot(r_out, rwid_int, 'r')

ax1.set_title('Blue side (20 plates)', fontsize=14)
ax1.set_xlabel('Wavelength [Angstrom]', fontsize=14)
ax1.set_ylabel('Row width [Angstrom/Pixel]', fontsize=14)
ax2.set_title('Red side (20 plates)', fontsize=14)
ax2.set_xlabel('Wavelength [Angstrom]', fontsize=14)
plt.tight_layout()
#plt.savefig('row_width.png')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,6))

ax1.plot(b_out, bres_int, 'b')
ax2.plot(r_out, rres_int, 'r')

ax1.set_title('Blue side (20 plates)', fontsize=14)
ax1.set_xlabel('Wavelength [Angstrom]', fontsize=14)
ax1.set_ylabel('FWHM Resolution [Angstrom]', fontsize=14)
ax2.set_title('Red Side (20 plates)', fontsize=14)
ax2.set_xlabel('Wavelength [Angstrom]', fontsize=14)
plt.tight_layout()
#plt.savefig('resolution.png')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,6))

ax1.plot(b_out, bnef_int, 'b')
ax2.plot(r_out, rnef_int, 'r')

ax1.set_title('Blue side (20 plates)', fontsize=14)
ax1.set_xlabel('Wavelength [Angstrom]', fontsize=14)
ax1.set_ylabel('neff [Pixel]', fontsize=14)
ax2.set_title('Red side (20 plates)', fontsize=14)
ax2.set_xlabel('Wavelength [Angstrom]', fontsize=14)
plt.tight_layout()
#plt.savefig('neff.png')
plt.show()

# %%
blue = Table([b_out*u.Angstrom, bres_int*u.Angstrom, bwid_int*u.Angstrom/u.pix, 
              bnef_int*u.pix], names=('wavelength', 'fwhm_wave', 'angstroms_per_row', 
                                                          'neff_spatial'))
red = Table([r_out*u.Angstrom, rres_int*u.Angstrom, rwid_int*u.Angstrom/u.pix, 
             rnef_int*u.pix], names=('wavelength', 'fwhm_wave', 'angstroms_per_row', 
                                                          'neff_spatial'))

# %%
blue.write('/Users/belaabolfathi/Data/desimodel/0.4.2/data/specpsf/eboss-blue.fits')
red.write('/Users/belaabolfathi/Data/desimodel/0.4.2/data/specpsf/eboss-red.fits')

# %%
np.max(red['wavelength'])
# Out:
# 10871.973225181586

# %% [markdown]
# ## Adjust data files to be within interpolation range

# %%
def adjust_interp(data, wlen_min, wlen_max, lo_val, hi_val, col1, col2):
    beg = np.arange(wlen_min, 3500, 0.1)
    end = np.arange(10000, wlen_max, 0.1)
    col_beg = np.full(len(beg), lo_val)
    col_end = np.full(len(end), hi_val)
    pad_beg = Table([beg, col_beg], names=(col1, col2))
    pad_end = Table([end, col_end], names=(col1, col2))
    new_data = data
    new_data = vstack([pad_beg,new_data])
    new_data = vstack([new_data, pad_end])
    return(new_data)

# %% [markdown]
# ### Update sky grid

# %%
spec_sky = Table.read('/Users/belaabolfathi/Data/desimodel/0.4.2/data/spectra/spec-sky.dat', format='ascii')
new_spec_sky = adjust_interp(data=spec_sky, wlen_min=2980, wlen_max=10920, lo_val=1.62666, hi_val=0.75561, col_name='FLUX')

# %%
new_spec_sky.write('/Users/belaabolfathi/Data/desimodel/0.4.2/data/spectra/eboss-spec-sky.dat', format='ascii', overwrite=True)

# %% [markdown]
# ### Update extinction

# %%
extinction = Table.read('/Users/belaabolfathi/Data/desimodel/0.4.2/data/spectra/ZenithExtinction-KPNO.dat', 
                        format='ascii')
new_ext = adjust_interp(data=extinction, wlen_min=2980, wlen_max=10920, lo_val=0.6, hi_val=0.022, col_name='EXTINCTION')

# %%
new_ext.write('/Users/belaabolfathi/Data/desimodel/0.4.2/data/spectra/eboss-KPNO-extinction.dat', format='ascii', overwrite=True)

# %% [markdown]
# ## Throughput

# %%
def get_frame_file(plan_path, sequence_number, band, fiber):
    local_plan_path = mirror.get(plan_path)
    Plan = bossdata.plate.Plan(local_plan_path)
    exp_name_plan = Plan.get_exposure_name(sequence_number=sequence_number, band=band, fiber=fiber, 
                                           ftype='spFrame')
    local_fits = mirror.get(os.path.join(plan_path.strip(os.path.basename(plan_path)), 
                                         exp_name_plan))
    spec_index = Plan.get_spectrograph_index(fiber=fiber)
    FrameFile = bossdata.plate.FrameFile(path=local_fits, index=spec_index, calibrated=False)
    return fits.open(local_fits), FrameFile 

def get_flat_file(plate, mjd, sequence_number, camera):
    remote_plate_spec_path = finder.get_plate_spec_path(plate=plate, mjd=mjd)
    plate_spec_path = mirror.get(remote_plate_spec_path)
    PlateFile = bossdata.plate.PlateFile(plate_spec_path)
    exp_name_plate = PlateFile.exposures.get_exposure_name(exposure_index=sequence_number, 
                                                      camera=camera, ftype='spFlat')
    remote_plate_path = finder.get_plate_path(plate=plate, filename=exp_name_plate)
    plate_path = mirror.get(remote_plate_path)
    return fits.open(plate_path)

def get_cframe_file(plan_path, sequence_number, band, fiber):
    local_plan_path = mirror.get(plan_path)
    Plan = bossdata.plate.Plan(local_plan_path)
    exp_name_plan = Plan.get_exposure_name(sequence_number=sequence_number, band=band, fiber=fiber, 
                                           ftype='spCFrame')
    local_fits = mirror.get(os.path.join(plan_path.strip(os.path.basename(plan_path)), 
                                         exp_name_plan))
    return fits.open(local_fits)

# %%
def get_standards(plate, mjd, fiber, band):
    
    sequence_number = 0
    
    plan_path = finder.get_plate_plan_path(plate=plate, mjd=mjd, combined=True)
    frame, FrameFile = get_frame_file(plan_path=plan_path, sequence_number=sequence_number, 
                                      band=band, fiber=fiber)
    flat = get_flat_file(plate=plate, mjd=mjd, sequence_number=sequence_number, camera=FrameFile.camera)
    cframe = get_cframe_file(plan_path=plan_path, sequence_number=sequence_number, 
                         band=band, fiber=fiber)
    std = []
    for i in range(len(cframe[5].data)):
        if cframe[5].data['OBJTYPE'][i] == 'SPECTROPHOTO_STD':
            std.append(i)
            
    return(frame, flat, cframe, std)

# %%
extinct_path = os.path.join(os.getenv('DESIMODEL'), 'data/spectra/ZenithExtinction-KPNO.dat')
extinct = loadtxt(extinct_path)

# %%
def response(frame, flat, cframe, fiber, nom_wlen, extinct=extinct):
    
    eflux = frame[0].data[fiber] # flux in flat-fielded electrons
    fiberflat = flat[0].data[fiber]
    superflat = frame[8].data[fiber]
    flux = cframe[0].data[fiber]
    electrons = eflux * superflat * fiberflat
    exp_time = cframe[0].header['EXPTIME'] #s
    wlen = 10**cframe[3].data[fiber] #check to see if matches frame[3].data
        
    flux = flux[:len(electrons)]
    wlen = wlen[:len(electrons)]
                
    flux_interp = np.interp(x=nom_wlen, xp=wlen, fp=flux)
    elec_interp = np.interp(x=nom_wlen, xp=wlen, fp=electrons)
    extinct_interp = np.interp(x=nom_wlen, xp=extinct[:,0], 
                               fp=extinct[:,1])
    
    
    airmass = cframe[0].header['AIRMASS']
    exp_time = cframe[0].header['EXPTIME']
    
    midpt = np.append((nom_wlen[1:]+nom_wlen[:-1])/2, nom_wlen[-1])
    
    r = 250./2 # cm
    mirror_area = np.pi*r**2 # cm^2 
    h = scipy.constants.Planck
    c = scipy.constants.c
    
    dlam = np.diff(nom_wlen)
    dlam = np.append(dlam, dlam[-1])
    
    
    num = flux_interp * mirror_area * exp_time * dlam 
    denom = h * c / midpt
    photons = num / denom * (10**(-34)) # convert from Joules to ergs

    exp = extinct_interp*airmass
    extinction = 10 ** (-exp/2.5)

    photons_ext = photons * extinction
    
    return(elec_interp/photons_ext)

# %%
def multi_plot(plate, mjd, fiber, band, wlen_min, wlen_max, plot=True, save=None):
    
    if fiber <= 499:
        f = 6
    else:
        f = 600
    
    frame, flat, cframe, stds = get_standards(plate, mjd, f, band)
    
    # star fibers are: stds[i]+1
    # but for indices in files it's stds[i]
    
    fiber = np.mod(fiber, 500)
    
    eflux = frame[0].data[fiber] # flux in flat-fielded electrons
    fiberflat = flat[0].data[fiber]
    superflat = frame[8].data[fiber]
    flux = cframe[0].data[fiber]
    electrons = eflux * superflat * fiberflat
    exp_time = cframe[0].header['EXPTIME'] #s
    wlen = 10**cframe[3].data[fiber] #check to see if matches frame[3].data
    
    #print(eflux.shape, superflat.shape, fiberflat.shape, electrons.shape)
    
    flux = flux[:len(electrons)]
    wlen = wlen[:len(electrons)]
    
    extinct_path = os.path.join(os.getenv('DESIMODEL'), 'data/spectra/ZenithExtinction-KPNO.dat')
    extinct = loadtxt(extinct_path)
    
    if band == 'blue':
        nom_wlen = b_out
    else:
        nom_wlen = r_out

    #print(nom_wlen.shape, wlen.shape, electrons.shape)
        
    flux_interp = np.interp(x=nom_wlen, xp=wlen, fp=flux)
    elec_interp = np.interp(x=nom_wlen, xp=wlen, fp=electrons)
    extinct_interp = np.interp(x=nom_wlen, xp=extinct[:,0], 
                               fp=extinct[:,1])
    
    superflat_interp = np.interp(x=nom_wlen, xp=wlen, 
                               fp=superflat)
    fiberflat_interp = np.interp(x=nom_wlen, xp=wlen, 
                               fp=fiberflat)
    
    
    airmass = cframe[0].header['AIRMASS']
    exp_time = cframe[0].header['EXPTIME']
    
    midpt = np.append((nom_wlen[1:]+nom_wlen[:-1])/2, nom_wlen[-1])
    
    r = 250./2 # cm
    mirror_area = np.pi*r**2 # cm^2 
    h = scipy.constants.Planck
    c = scipy.constants.c
    
    dlam = np.diff(nom_wlen)
    dlam = np.append(dlam, dlam[-1])
    
    
    num = flux_interp * mirror_area * exp_time * dlam 
    denom = h * c / midpt
    photons = num / denom * (10**(-34)) # convert from Joules to ergs

    exp = extinct_interp*airmass
    extinction = 10 ** (-exp/2.5)

    photons_ext = photons * extinction
    
    if f == 600:
        fiber_num = fiber+500
    else:
        fiber_num = fiber
    
    if plot:
    
        fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6), (ax7, ax8)) = plt.subplots(4,2, figsize=(11,11))

        #fig.suptitle('{} \n (plate={}, mjd={}, fiber={})'.format(cframe[5].data['OBJTYPE'][fiber], plate, mjd, fiber_num+1, 
                                                              #fontsize=14, fontweight='bold'), y=1.02)

        ax1.scatter(nom_wlen, flux_interp, alpha=0.3, s=1)
        ax1.set_title('Calibrated flux')
        ax1.set_xlabel('Wavelength [Angstrom]')
        ax1.set_ylabel(r'Flux $[10^{-17}$ erg/s/cm$^2$/A]')
        ax1.set_xlim(wlen_min, wlen_max)
        flux_min, flux_max = np.percentile(flux_interp, (1, 99))
        ax1.set_ylim(0, flux_max)

        ax2.scatter(nom_wlen, photons, alpha=0.3, s=1)
        ax2.set_title('Photons entering atmosphere')
        ax2.set_xlabel('Wavelength [Angstrom]')
        ax2.set_ylabel('# Photons')
        ax2.set_xlim(wlen_min, wlen_max)
        photon_min, photon_max = np.percentile(photons, (1,99))
        ax2.set_ylim(0, photon_max)

        ax7.scatter(nom_wlen, elec_interp, alpha=0.3, s=1)
        ax7.set_title('Electrons')
        ax7.set_xlabel('Wavelength [Angstrom]')
        ax7.set_ylabel('# Electrons')
        ax7.set_xlim(wlen_min, wlen_max)
        elec_min, elec_max = np.percentile(elec_interp, (1,99))
        ax7.set_ylim(0, elec_max+50)

        ax3.scatter(nom_wlen, extinction, alpha=0.3, s=1)
        ax3.set_title('Extinction')
        ax3.set_xlabel('Wavelength [Angstrom]')
        ax3.set_ylabel('Extinction')
        ax3.set_xlim(wlen_min, wlen_max)
        ex_min, ex_max = np.percentile(extinct, (1,99))
        ax3.set_ylim(0, 1.1)

        ax5.scatter(nom_wlen, superflat_interp, alpha=0.3, s=1)
        ax5.set_title('Superflat')
        ax5.set_xlabel('Wavelength [Angstrom]')
        ax5.set_ylabel('# Electrons')
        ax5.set_xlim(wlen_min, wlen_max)
        sup_min, sup_max = np.percentile(superflat_interp, (1,99))
        ax5.set_ylim(0, 1.8)

        ax6.scatter(nom_wlen, fiberflat_interp, alpha=0.3, s=1)
        ax6.set_title('Fiberflat')
        ax6.set_xlabel('Wavelength [Angstrom]')
        ax6.set_ylabel('# Electrons')
        ax6.set_xlim(wlen_min, wlen_max)
        ax6.set_ylim(0, 1.1)

        ax4.scatter(nom_wlen, photons_ext, alpha=0.3, s=1)
        ax4.set_title('Photons entering telescope')
        ax4.set_xlabel('Wavelength [Angstrom]')
        ax4.set_ylabel('# Electrons')
        ax4.set_xlim(wlen_min, wlen_max)
        photons_ext_min, photons_ext_max = np.percentile(photons_ext, (1,99))
        ax4.set_ylim(0, photons_ext_max)

        ax8.scatter(nom_wlen, elec_interp/photons_ext, alpha=0.3, s=1)
        ax8.set_title('Fiberloss x Throughput')
        ax8.set_xlabel('Wavelength [Angstrom]')
        ax8.set_ylabel('# Electrons / # Photons')
        ax8.set_xlim(wlen_min, wlen_max)
        ax8.set_ylim(0,0.25)

        plt.tight_layout()

        if save:
            plt.savefig(save)

        plt.show()        
        
    return(nom_wlen, elec_interp/photons_ext, flux_interp)

# %%
frame, flat, cframe, stds = get_standards(plates[0], mjds[0], 600, 'red')
stds
# Out:
# [9, 36, 97, 158, 276, 327, 334, 344, 408, 436, 474, 483, 494]

# %%
cframe[5].data['OBJTYPE'][158]
# Out:
# 'SPECTROPHOTO_STD'

# %%
494+500
# Out:
# 994

# %%
np.mod(658, 500)
# Out:
# 158

# %%
wlen, thru, flux = multi_plot(plate=6511, mjd=56540, fiber=41, band='blue', wlen_min=3000, wlen_max=7500)
# Out:
# /Users/belaabolfathi/anaconda3/envs/bossdata/lib/python2.7/site-packages/ipykernel/__main__.py:139: RuntimeWarning: divide by zero encountered in divide
# /Users/belaabolfathi/anaconda3/envs/bossdata/lib/python2.7/site-packages/ipykernel/__main__.py:139: RuntimeWarning: invalid value encountered in divide
# /Users/belaabolfathi/anaconda3/envs/bossdata/lib/python2.7/site-packages/ipykernel/__main__.py:153: RuntimeWarning: divide by zero encountered in divide
# /Users/belaabolfathi/anaconda3/envs/bossdata/lib/python2.7/site-packages/ipykernel/__main__.py:153: RuntimeWarning: invalid value encountered in divide

# %%
wlen, thru, flux = multi_plot(plate=6511, mjd=56540, fiber=41, band='red', wlen_min=6000, wlen_max=10000)
# Out:
# /Users/belaabolfathi/anaconda3/envs/bossdata/lib/python2.7/site-packages/ipykernel/__main__.py:139: RuntimeWarning: invalid value encountered in divide
# /Users/belaabolfathi/anaconda3/envs/bossdata/lib/python2.7/site-packages/ipykernel/__main__.py:153: RuntimeWarning: invalid value encountered in divide

# %%
wlen, thru, flux = multi_plot(plate=plates[0], mjd=mjds[0], fiber=658, band='red', wlen_min=6000, wlen_max=10000)
# Out:
# /Users/belaabolfathi/anaconda3/envs/bossdata/lib/python2.7/site-packages/ipykernel/__main__.py:139: RuntimeWarning: divide by zero encountered in divide
# /Users/belaabolfathi/anaconda3/envs/bossdata/lib/python2.7/site-packages/ipykernel/__main__.py:139: RuntimeWarning: invalid value encountered in divide
# /Users/belaabolfathi/anaconda3/envs/bossdata/lib/python2.7/site-packages/ipykernel/__main__.py:153: RuntimeWarning: divide by zero encountered in divide
# /Users/belaabolfathi/anaconda3/envs/bossdata/lib/python2.7/site-packages/ipykernel/__main__.py:153: RuntimeWarning: invalid value encountered in divide

# %%
# fiber parameter must be index if on r1/b1, index+500 if r2/b2
wlen, thru, flux = multi_plot(plate=plates[0], mjd=mjds[0], fiber=96, band='red', wlen_min=6000, wlen_max=10000, save='multiplot-7027-56448-97.png')
# Out:
# /Users/belaabolfathi/anaconda3/envs/bossdata/lib/python2.7/site-packages/ipykernel/__main__.py:139: RuntimeWarning: invalid value encountered in divide
# /Users/belaabolfathi/anaconda3/envs/bossdata/lib/python2.7/site-packages/ipykernel/__main__.py:153: RuntimeWarning: invalid value encountered in divide

# %%
fr1b, f1b, c1b, s1b = get_standards(plates[0], mjds[0], 6, 'blue')
fr1r, f1r, c1r, s1r = get_standards(plates[0], mjds[0], 6, 'red')
fr2b, f2b, c2b, s2b = get_standards(plates[0], mjds[0], 600, 'blue')
fr2r, f2r, c2r, s2r = get_standards(plates[0], mjds[0], 600, 'red')

# %%
print(s1b)
print(s1r)
print(s2b)
print(s2r)
# Out:
# [30, 55, 96, 157, 167, 316, 458]
# [30, 55, 96, 157, 167, 316, 458]
# [9, 36, 97, 158, 276, 327, 334, 344, 408, 436, 474, 483, 494]
# [9, 36, 97, 158, 276, 327, 334, 344, 408, 436, 474, 483, 494]

# %%
for i, star in enumerate(s1r):
    print(star, c1r[5].data['OBJTYPE'][star])
# Out:
# (30, 'SPECTROPHOTO_STD')
# (55, 'SPECTROPHOTO_STD')
# (96, 'SPECTROPHOTO_STD')
# (157, 'SPECTROPHOTO_STD')
# (167, 'SPECTROPHOTO_STD')
# (316, 'SPECTROPHOTO_STD')
# (458, 'SPECTROPHOTO_STD')

# %%
def all_plate_thru(plate, mjd):
    
    # left-half
    fr1b, f1b, c1b, s1b = get_standards(plate, mjd, 6, 'blue')
    fr1r, f1r, c1r, s1r = get_standards(plate, mjd, 6, 'red')
    
    # right-half
    fr2b, f2b, c2b, s2b = get_standards(plate, mjd, 600, 'blue')
    fr2r, f2r, c2r, s2r = get_standards(plate, mjd, 600, 'red')
    
    assert len(s1b) == len(s1r)
    assert len(s2b) == len(s2r)
    
    thru_b1 = np.empty((len(s1b), len(b_out)), dtype=float)
    thru_r1 = np.empty((len(s1r), len(r_out)), dtype=float)
    thru_b2 = np.empty((len(s2b), len(b_out)), dtype=float)
    thru_r2 = np.empty((len(s2r), len(r_out)), dtype=float)
    
    for i, star1 in enumerate(s1b):
    
        thru_b1[i] = response(fr1b, f1b, c1b, star1, b_out)
        thru_r1[i] = response(fr1r, f1r, c1r, star1, r_out)
        
    for j, star2 in enumerate(s2b):
        
        thru_b2[j] = response(fr2b, f2b, c2b, star2, b_out)
        thru_r2[j] = response(fr2r, f2r, c2r, star2, r_out)

    all_b = np.concatenate((thru_b1, thru_b2), axis=0)
    all_r = np.concatenate((thru_r1, thru_r2), axis=0)
    
    return(all_b, all_r)

# %%
plates[0], mjds[0]
# Out:
# (7027, 56448)

# %%
thru_b, thru_r = all_plate_thru(plates[0], mjds[0])
# Out:
# /Users/belaabolfathi/anaconda3/envs/bossdata/lib/python2.7/site-packages/ipykernel/__main__.py:43: RuntimeWarning: divide by zero encountered in divide
# /Users/belaabolfathi/anaconda3/envs/bossdata/lib/python2.7/site-packages/ipykernel/__main__.py:43: RuntimeWarning: invalid value encountered in divide

# %%
plt.figure(figsize=(10,7))

for i in range(len(thru_r)):
    plt.scatter(r_out, thru_r[i], alpha=0.3, s=1)
plt.ylim(0,0.3)
# Out:
# (0, 0.3)

# %%
plt.figure(figsize=(10,7))

for i in range(len(thru_b)):
    plt.scatter(b_out, thru_b[i], alpha=0.3, s=1)
plt.ylim(0,0.3)
# Out:
# (0, 0.3)

# %%
plt.figure(figsize=(10,7))

for i in range(len(thru_b)):
    plt.scatter(b_out, thru_b[i], alpha=0.3, s=1)

# %%
plt.figure(figsize=(10,7))

for j in range(len(plates[:1])):
    
    fr, fl, c1, s1 = get_standards(plates[j], mjds[j], 6, 'red')
    fr, fl, c2, s2 = get_standards(plates[j], mjds[j], 600, 'red')

    thru_all1 = np.empty((len(s1), len(r_out)), dtype=float)
    thru_all2 = np.empty((len(s2), len(r_out)), dtype=float)


    s2 = np.asarray(s2)+500

    for i, star1 in enumerate(s1): # star is index, not fiber number (star_fiber = star_index + 1)
        wlen, thru_all1[i], flux = multi_plot(plate=plates[j], mjd=mjds[j], fiber=star1, band='red', 
                                              wlen_min=5500, wlen_max=11000, plot=False, save=None)
        print(c1[5].data['OBJTYPE'][np.mod(star1,500)])
        plt.scatter(wlen, thru_all1[i], alpha=0.3, s=1)

    for k, star2 in enumerate(s2):
        wlen, thru_all2[k], flux = multi_plot(plate=plates[j], mjd=mjds[j], fiber=star2, band='red', 
                                              wlen_min=5500, wlen_max=11000, plot=False, save=None)
        print(c2[5].data['OBJTYPE'][np.mod(star2,500)])
        plt.scatter(wlen, thru_all2[k], alpha=0.3, s=1)


plt.title('All standard stars', fontsize=16)
plt.xlabel('Wavelength [Angstrom]', fontsize=14)
plt.ylabel('Fiberloss x throughput', fontsize=14)
plt.ylim(0,0.3)
plt.show()
# Out:
# /Users/belaabolfathi/anaconda3/envs/bossdata/lib/python2.7/site-packages/ipykernel/__main__.py:153: RuntimeWarning: invalid value encountered in divide
# SPECTROPHOTO_STD
# /Users/belaabolfathi/anaconda3/envs/bossdata/lib/python2.7/site-packages/ipykernel/__main__.py:153: RuntimeWarning: divide by zero encountered in divide
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD

# %%
plt.figure(figsize=(10,7))

for j in range(len(plates[:1])):
    
    fr, fl, c1, s1 = get_standards(plates[j], mjds[j], 6, 'blue')
    fr, fl, c2, s2 = get_standards(plates[j], mjds[j], 600, 'blue')

    thru_all1 = np.empty((len(s1), len(b_out)), dtype=float)
    thru_all2 = np.empty((len(s2), len(b_out)), dtype=float)


    s2 = np.asarray(s2)+500

    for i, star1 in enumerate(s1): # star is index, not fiber number (star_fiber = star_index + 1)
        wlen, thru_all1[i], flux = multi_plot(plate=plates[j], mjd=mjds[j], fiber=star1, band='blue', 
                                              wlen_min=3500, wlen_max=7500, plot=False, save=None)
        print(c1[5].data['OBJTYPE'][np.mod(star1,500)])
        plt.scatter(wlen, thru_all1[i], alpha=0.3, s=1)

    for k, star2 in enumerate(s2):
        wlen, thru_all2[k], flux = multi_plot(plate=plates[j], mjd=mjds[j], fiber=star2, band='blue', 
                                              wlen_min=3500, wlen_max=7500, plot=False, save=None)
        print(c2[5].data['OBJTYPE'][np.mod(star2,500)])
        plt.scatter(wlen, thru_all2[k], alpha=0.3, s=1)


plt.title('All standard stars', fontsize=16)
plt.xlabel('Wavelength [Angstrom]', fontsize=14)
plt.ylabel('Fiberloss x throughput', fontsize=14)
plt.ylim(0,0.3)
plt.savefig('/Users/belaabolfathi/Desktop/blue_stds.png')
plt.show()
# Out:
# /Users/belaabolfathi/anaconda3/envs/bossdata/lib/python2.7/site-packages/ipykernel/__main__.py:153: RuntimeWarning: divide by zero encountered in divide
# /Users/belaabolfathi/anaconda3/envs/bossdata/lib/python2.7/site-packages/ipykernel/__main__.py:153: RuntimeWarning: invalid value encountered in divide
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD

# %% [markdown]
# ## Don't run this

# %%
plt.figure(figsize=(10,7))

for j in range(len(plates[:1])):

    fr, fl, c1, s1 = get_standards(plates[j], mjds[j], 6, 'blue')
    fr, fl, c2, s2 = get_standards(plates[j], mjds[j], 600, 'blue')

    thru_all1 = np.empty((len(s1), len(r_out)), dtype=float)
    thru_all2 = np.empty((len(s2), len(r_out)), dtype=float)


    s2 = np.asarray(s2)+500

    for i, star in enumerate(s1): # star is index, not fiber number (star_fiber = star_index + 1)
        wlen, thru_all1[i], flux = multi_plot(plate=plates[j], mjd=mjds[j], fiber=star, band='blue', wlen_min=3500, wlen_max=7500, plot=False, save=None)
        print(c1[5].data['OBJTYPE'][np.mod(star,500)])
        plt.scatter(wlen, thru_all[i], alpha=0.3, s=1)

    for k, star2 in enumerate(s2):
        wlen, thru_all2[k], flux = multi_plot(plate=plates[j], mjd=mjds[j], fiber=star2, band='blue', wlen_min=3500, wlen_max=7500, plot=False, save=None)
        print(c2[5].data['OBJTYPE'][np.mod(star2,500)])
        plt.scatter(wlen, thru_all2[k], alpha=0.3, s=1)


plt.title('All standard stars', fontsize=16)
plt.xlabel('Wavelength [Angstrom]', fontsize=14)
plt.ylabel('Fiberloss x throughput', fontsize=14)
plt.ylim(0,0.3)
plt.savefig('stds_thru_blue{}-{}.png'.format(plates[j], mjds[j]))
plt.show()
# Out:
# /Users/belaabolfathi/anaconda3/envs/bossdata/lib/python2.7/site-packages/ipykernel/__main__.py:153: RuntimeWarning: divide by zero encountered in divide
# /Users/belaabolfathi/anaconda3/envs/bossdata/lib/python2.7/site-packages/ipykernel/__main__.py:153: RuntimeWarning: invalid value encountered in divide
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD
# SPECTROPHOTO_STD

# %%
thru_all1.shape, thru_all2.shape
# Out:
# ((7, 3972), (13, 3972))

# %%
c[5].data['OBJTYPE'] # why does sky server have way more stars than spectrophoto_std's?
# Out:
# chararray(['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'SKY', 'NA', 'NA',
#        'SPECTROPHOTO_STD', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA',
#        'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA',
#        'NA', 'NA', 'NA', 'NA', 'NA', 'SKY', 'NA', 'SPECTROPHOTO_STD', 'NA',
#        'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA',
#        'NA', 'NA', 'NA', 'NA', 'SKY', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA',
#        'NA', 'NA', 'NA', 'NA', 'NA', 'SKY', 'NA', 'NA', 'NA', 'NA', 'NA',
#        'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA',
#        'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA',
#        'NA', 'NA', 'NA', 'NA', 'SPECTROPHOTO_STD', 'NA', 'NA', 'NA', 'NA',
#        'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA',
#        'NA', 'NA', 'NA', 'SKY', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA',
#        'NA', 'NA', 'SKY', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA',
# ...

# %%
def get_std_params(plate, mjd, fiber, band):

    frame, flat, cframe, stds = get_standards(plate, mjd, fiber, band)
    

    focal_pos = np.empty((len(stds), 2), dtype=float)
    fiber_num = np.empty((len(stds), 1), dtype=float)
    cart_num = np.empty((len(stds), 1), dtype=float)
    am =  np.empty((len(stds), 1), dtype=float)
    et = np.empty((len(stds), 1), dtype=float)

    for i, star in enumerate(stds):
            
        focal_pos[i][0] = cframe[5].data['XFOCAL'][star]
        focal_pos[i][1] = cframe[5].data['YFOCAL'][star]
        fiber_num[i] = star
        cart_num[i] = cframe[0].header['CARTID']
        am[i] = cframe[0].header['AIRMASS']
        et[i] = cframe[0].header['EXPTIME']
        
    return(focal_pos, fiber_num, cart_num, am, et)

# %%
def get_features(thru, total_flux, focal_pos):
    num = thru.shape[0]
    mean_thru = np.empty(num, dtype=float)
    mean_flux = np.empty(num, dtype=float)
    for i in range(num):
        mean_thru[i] = np.mean(thru[i])
        mean_flux[i] = np.mean(total_flux[i])
    x = focal_pos[:,0]
    y = focal_pos[:,1]
    r = np.sqrt(x ** 2 + y ** 2)
    return(mean_thru, mean_flux, r)

# %%
plt.scatter(et, mean_thru)
plt.xlim(0.025,0.225)
# Out:
# (0.025, 0.225)

# %%
wlen_min=4950.
wlen_max=5050.

num_plates = 10

fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6)) = plt.subplots(3, 2, figsize=(10,10))
fig.suptitle('All standards on {} plates'.format(num_plates), y=1.025, fontsize=16)

for half in [6,600]:
    
    for i in range(len(plates[:num_plates])):

        fr, fl, c, s = get_standards(plates[i], mjds[i], half, 'blue')

        thru_all = np.empty((len(s), len(b_out)), dtype=float)
        flux_all = np.empty((len(s), len(b_out)), dtype=float)
        
        if half == 600:
            s = np.asarray(s)+500

        for j, star in enumerate(s):
            wlen, thru_all[j], flux_all[j] = multi_plot(plate=plates[i], mjd=mjds[i], fiber=star, band='blue', 
                                                        wlen_min=6000, wlen_max=10000, plot=False)
        
        focal_pos, fiber_num, cart_num, am, et = get_std_params(plate=plates[i], mjd=mjds[i], fiber=half, band='blue')
        
        lower = wlen > wlen_min
        upper = wlen < wlen_max

        mean_thru, mean_flux, r = get_features(thru_all[:, lower & upper], flux_all[:, lower & upper], focal_pos)

        ax1.scatter(et, mean_thru)
        ax2.scatter(r, mean_thru)
        ax3.scatter(fiber_num, mean_thru)
        ax4.scatter(mean_flux, mean_thru)
        ax5.scatter(cart_num, mean_thru)
        ax6.scatter(am, mean_thru)

    
ax1.set_xlabel('Exposure time')
ax1.set_ylabel('Mean throughput') 
ax2.set_xlabel('Radial distance on plate')
ax2.set_ylabel('Mean throughput')
ax3.set_xlabel('Fiber number')
ax3.set_ylabel('Mean throughput')
ax4.set_xlabel('Mean flux')
ax4.set_ylabel('Mean throughput')
ax5.set_xlabel('Cartridge number')
ax5.set_ylabel('Mean throughput')
ax6.set_xlabel('Airmass')
ax6.set_ylabel('Mean throughput')


plt.tight_layout()
plt.savefig('throughput_anomalies_blue.png')
plt.show()
# Out:
# /Users/belaabolfathi/anaconda3/envs/bossdata/lib/python2.7/site-packages/ipykernel/__main__.py:153: RuntimeWarning: divide by zero encountered in divide
# /Users/belaabolfathi/anaconda3/envs/bossdata/lib/python2.7/site-packages/ipykernel/__main__.py:153: RuntimeWarning: invalid value encountered in divide

# %% [markdown]
# ## Downsample

# %%
# Take median, then downsample

# %%
# Do this for all 20 plates

# %%
print('All standards on: plate={}, mjd={}').format(plates[0], mjds[0])
# Out:
# All standards on: plate=7027, mjd=56448

# %%
thru_all1.shape, thru_all2.shape
# Out:
# ((7, 3972), (13, 3972))

# %%
total_thru = np.concatenate((thru_all1,thru_all2), axis=0)
med_thru = np.median(total_thru, axis=0)
# Out:
# /Users/belaabolfathi/anaconda3/envs/bossdata/lib/python2.7/site-packages/numpy/lib/function_base.py:3858: RuntimeWarning: Invalid value encountered in median for 775 results
#   r = func(a, **kwargs)

# %%
thru_b.shape, thru_r.shape
# Out:
# ((20, 3972), (20, 3972))

# %%
med_thru_b = np.median(thru_b, axis=0)
med_thru_r = np.median(thru_r, axis=0)
# Out:
# /Users/belaabolfathi/anaconda3/envs/bossdata/lib/python2.7/site-packages/numpy/lib/function_base.py:3858: RuntimeWarning: Invalid value encountered in median for 1300 results
#   r = func(a, **kwargs)
# /Users/belaabolfathi/anaconda3/envs/bossdata/lib/python2.7/site-packages/numpy/lib/function_base.py:3858: RuntimeWarning: Invalid value encountered in median for 775 results
#   r = func(a, **kwargs)

# %%
plt.figure(figsize=(10,7))
plt.scatter(r_out, med_thru, s=1, alpha=0.3)
plt.title("Median of all standard stars", fontsize=16)
plt.xlabel('Wavelength [Angstrom]', fontsize=14)
plt.ylabel('Fiberloss x throughput', fontsize=14)
plt.ylim(0,0.3)
plt.savefig('/Users/belaabolfathi/Desktop/red_median.png')
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.scatter(r_out, med_thru, s=1, alpha=0.3)
plt.title("Median of all standard stars", fontsize=16)
plt.xlabel('Wavelength [Angstrom]', fontsize=14)
plt.ylabel('Fiberloss x throughput', fontsize=14)
plt.ylim(0,0.3)
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.scatter(r_out, med_thru, s=1, alpha=0.3)
plt.title("Median of all standard stars", fontsize=16)
plt.xlabel('Wavelength [Angstrom]', fontsize=14)
plt.ylabel('Fiberloss x throughput', fontsize=14)
plt.ylim(0,0.3)
plt.savefig('med_stds_thru_blue{}-{}.png'.format(plates[0], mjds[0]))
plt.show()

# %%
N/7.
# Out:
# 567.4285714285714

# %%
N/160.
# Out:
# 24.825

# %%
N = len(b_out)
m = 200
p = int(np.floor(N/float(m)))

# %%
test = np.mean(med_thru[:p*m].reshape(p,m), axis=1)
test_wlen = np.mean(r_out[:p*m].reshape(p,m), axis=1)

# %%
plt.plot(test_wlen, test)
#plt.plot(test_wlen1, test1)

# %%
def downsample(nom_wlen, med_thru, m, save=None):
    
    N = len(nom_wlen)
    p = int(np.floor(N/float(m)))
    
    dwn_thru = np.median(med_thru[:p*m].reshape(p,m), axis=1)
    xp = np.median(nom_wlen[:p*m].reshape(p,m), axis=1)
    
    dwn_thru_mean = np.mean(med_thru[:p*m].reshape(p,m), axis=1)
    xp_mean = np.mean(nom_wlen[:p*m].reshape(p,m), axis=1)
    
    #dwn_thru = np.median(med_thru.reshape(N/m, m), axis=1)
    #xp = np.median(nom_wlen.reshape(N/m,m), axis=1)
    
    #dwn_thru_mean = np.mean(med_thru.reshape(N/m, m), axis=1)
    #xp_mean = np.mean(nom_wlen.reshape(N/m,m), axis=1)
    
    fig, (ax1, ax2) = plt.subplots(1,2, figsize=(18,7), sharey=True)
    
    ax1.plot(xp, dwn_thru, 'm', label='Median', lw=4)
    ax1.scatter(nom_wlen, med_thru, s=1, alpha=0.3, label='Pre-downsampled')
    ax2.plot(xp_mean, dwn_thru_mean, 'm', label='Mean', lw=4)
    ax2.scatter(nom_wlen, med_thru, s=1, alpha=0.3, label='Pre-downsampled')
    fig.suptitle('Downsampled (N={}, m={})'.format(N, m), x=0.52, fontsize=16)
    ax1.set_ylabel('Fiberloss x throughput', fontsize=14)
    ax1.set_xlabel('Wavelength [Angstrom]', fontsize=14)
    ax2.set_xlabel('Wavelength [Angstrom]', fontsize=14)
    ax1.set_ylim(0,0.33)
    
    ax1.legend(fontsize=14)
    ax2.legend(fontsize=14)
    
    if save:
        plt.savefig(save)
        
    plt.tight_layout()
    plt.subplots_adjust(top=0.93)
    
    plt.show()
    
    return(xp, dwn_thru)
    
    '''
    
    l = []
    for i in range(len(nom_wlen)):
        if np.mod(i,m) == 0:
            l.append(nom_wlen[i])
    print(np.min(np.diff(l)), np.max(np.diff(l)))
    #print(len(l), N/m)
    '''

# %%
b_wlen, dwn_b = downsample(b_out, med_thru, 100, save='/Users/belaabolfathi/Desktop/blue_downsampled.png')

# %%
r_wlen, dwn_r = downsample(r_out, med_thru, 100, save='/Users/belaabolfathi/Desktop/red_downsampled.png')
# Out:
# /Users/belaabolfathi/anaconda3/envs/bossdata/lib/python2.7/site-packages/numpy/lib/function_base.py:3858: RuntimeWarning: Invalid value encountered in median for 8 results
#   r = func(a, **kwargs)

# %%
b_wlen, dwn_b = downsample(b_out, med_thru_b, 100)
# Out:
# /Users/belaabolfathi/anaconda3/envs/bossdata/lib/python2.7/site-packages/numpy/lib/function_base.py:3858: RuntimeWarning: Invalid value encountered in median for 13 results
#   r = func(a, **kwargs)

# %%
r_wlen, dwn_r = downsample(r_out, med_thru_r, 100)
# Out:
# /Users/belaabolfathi/anaconda3/envs/bossdata/lib/python2.7/site-packages/numpy/lib/function_base.py:3858: RuntimeWarning: Invalid value encountered in median for 8 results
#   r = func(a, **kwargs)

# %%
downsample(b_out, med_thru, 100, save='downsampled_blue.png')

# %%
downsample(r_out, med_thru, 100, save='stds_downsampled.png')

# %%
for i in range(1987):
    if np.mod(len(r_out), i) == 0:
        print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 6
# 12
# 331
# 662
# 993
# 1324
# 1986
# /Users/belaabolfathi/anaconda3/envs/bossdata/lib/python2.7/site-packages/ipykernel/__main__.py:2: RuntimeWarning: divide by zero encountered in remainder
#   from ipykernel import kernelapp as app

# %%
np.diff(r_out)
# Out:
# array([ 1.39902164,  1.39902164,  1.39902164, ...,  1.39902164,
#         1.39902164,  1.39902164])

# %%
np.diff(b_out)
# Out:
# array([ 1.0390596,  1.0390596,  1.0390596, ...,  1.0390596,  1.0390596,
#         1.0390596])

# %% [markdown]
# # Generate throughput files

# %%
plt.plot(r_wlen, dwn_r, c='m')
plt.plot(r_wlen, dwn_r/0.55, c='g')
plt.show()

# %%
plt.plot(b_wlen, dwn_b, c='m')
plt.plot(b_wlen, dwn_b/0.55, c='g')
plt.show()

# %%
b_thru = dwn_b/0.55
r_thru = dwn_r/0.55

# %%
eboss_thru_b = Table([b_wlen, b_thru], names=('wavelength', 'throughput'))
eboss_thru_r = Table([r_wlen, r_thru], names=('wavelength', 'throughput'))

# %%
eboss_thru_b.write('/Users/belaabolfathi/Data/desimodel/0.4.2/data/throughput/eboss-thru-b.fits', overwrite=True)
eboss_thru_r.write('/Users/belaabolfathi/Data/desimodel/0.4.2/data/throughput/eboss-thru-r.fits', overwrite=True)

# %% [markdown]
# ## Fiberloss

# %% [markdown]
# ### Update fiberloss

# %%
qso_fiberloss = Table.read('/Users/belaabolfathi/Data/desimodel/0.4.2/data/throughput/fiberloss-qso.dat', 
                           format='ascii')
elg_fiberloss = Table.read('/Users/belaabolfathi/Data/desimodel/0.4.2/data/throughput/fiberloss-elg.dat', 
                           format='ascii')
lrg_fiberloss = Table.read('/Users/belaabolfathi/Data/desimodel/0.4.2/data/throughput/fiberloss-lrg.dat', 
                           format='ascii')
star_fiberloss = Table.read('/Users/belaabolfathi/Data/desimodel/0.4.2/data/throughput/fiberloss-star.dat', 
                           format='ascii')
sky_fiberloss = Table.read('/Users/belaabolfathi/Data/desimodel/0.4.2/data/throughput/fiberloss-sky.dat', 
                           format='ascii')
perf_fiberloss = Table.read('/Users/belaabolfathi/Data/desimodel/0.4.2/data/throughput/fiberloss-perfect.dat', 
                           format='ascii')

# %%
new_qso_fiberloss = adjust_interp(data=qso_fiberloss, wlen_min=2980, wlen_max=10920, 
                                  lo_val=qso_fiberloss['col2'][0], 
                                  hi_val=qso_fiberloss['col2'][-1], col1='col1', col2='col2')
new_elg_fiberloss = adjust_interp(data=elg_fiberloss, wlen_min=2980, wlen_max=10920, 
                                  lo_val=elg_fiberloss['col2'][0], 
                                  hi_val=elg_fiberloss['col2'][-1], col1='col1', col2='col2')
new_lrg_fiberloss = adjust_interp(data=lrg_fiberloss, wlen_min=2980, wlen_max=10920, 
                                  lo_val=lrg_fiberloss['col2'][0], 
                                  hi_val=lrg_fiberloss['col2'][-1], col1='col1', col2='col2')
new_star_fiberloss = adjust_interp(data=star_fiberloss, wlen_min=2980, wlen_max=10920, 
                                  lo_val=star_fiberloss['col2'][0], 
                                  hi_val=star_fiberloss['col2'][-1], col1='col1', col2='col2')
new_sky_fiberloss = adjust_interp(data=sky_fiberloss, wlen_min=2980, wlen_max=10920, 
                                  lo_val=sky_fiberloss['col2'][0], 
                                  hi_val=sky_fiberloss['col2'][-1], col1='col1', col2='col2')
new_perf_fiberloss = adjust_interp(data=perf_fiberloss, wlen_min=2980, wlen_max=10920, 
                                  lo_val=perf_fiberloss['col2'][0], 
                                  hi_val=perf_fiberloss['col2'][-1], col1='col1', col2='col2')

# %%
new_qso_fiberloss.write('/Users/belaabolfathi/Data/desimodel/0.4.2/data/throughput/eboss-fiberloss-qso.dat', 
                        format='ascii', overwrite=True)
new_elg_fiberloss.write('/Users/belaabolfathi/Data/desimodel/0.4.2/data/throughput/eboss-fiberloss-elg.dat', 
                        format='ascii', overwrite=True)
new_lrg_fiberloss.write('/Users/belaabolfathi/Data/desimodel/0.4.2/data/throughput/eboss-fiberloss-lrg.dat', 
                        format='ascii', overwrite=True)
new_star_fiberloss.write('/Users/belaabolfathi/Data/desimodel/0.4.2/data/throughput/eboss-fiberloss-star.dat', 
                        format='ascii', overwrite=True)
new_sky_fiberloss.write('/Users/belaabolfathi/Data/desimodel/0.4.2/data/throughput/eboss-fiberloss-sky.dat', 
                        format='ascii', overwrite=True)
new_perf_fiberloss.write('/Users/belaabolfathi/Data/desimodel/0.4.2/data/throughput/eboss-fiberloss-perfect.dat', 
                        format='ascii', overwrite=True)

# %%
fiberloss_star = Table.read('/Users/belaabolfathi/Data/desimodel/0.4.2/data/throughput/fiberloss-star.dat', format='ascii')

# %%
fiberloss_b = np.interp(b_out, fiberloss_star['col1'], fiberloss_star['col2'])
fiberloss_r = np.interp(r_out, fiberloss_star['col1'], fiberloss_star['col2'])

# %%
new_dwnb = np.interp(b_out, b_wlen, dwn_b)
new_dwnr = np.interp(r_out, r_wlen, dwn_r)

# %%
plt.scatter(b_out, fiberloss_b, s=1)
plt.scatter(b_out, new_dwnb, s=1)

# %%
plt.figure(figsize=(10,7))
plt.scatter(b_out, new_dwnb/fiberloss_b, s=1)
#plt.scatter(b_out, new_dwnb, s=1)
#plt.title('Blue side throughput', fontsize=16)
plt.xlabel('Wavelength [Angstrom]', fontsize=14)
plt.ylabel('Throughput', fontsize=14)
plt.savefig('/Users/belaabolfathi/Desktop/blue_thru.png')
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.scatter(r_out, new_dwnr/fiberloss_r, s=1, c='r')
#plt.scatter(b_out, new_dwnb, s=1)
#plt.title('Blue side throughput', fontsize=16)
plt.xlabel('Wavelength [Angstrom]', fontsize=14)
plt.ylabel('Throughput', fontsize=14)
plt.savefig('/Users/belaabolfathi/Desktop/red_thru.png')
plt.show()

# %%
plt.scatter(r_out, new_dwnr/fiberloss_r, s=1)
plt.scatter(r_out, new_dwnr, s=1)
plt.ylim(0,0.3)
plt.show()

# %% [markdown]
# ## Stellar calibration vector -- this is model, we want stellar model

# %%
remote_plan = finder.get_plate_plan_path(plate=plates[0], mjd=mjds[0], combined=True)
local_plan = mirror.get(remote_plan)

# %%
def get_camera_data(band):
    Plan = bossdata.plate.Plan(local_plan)
    exp_name = Plan.get_exposure_name(sequence_number=0, band=band, fiber=1, ftype='spFluxcalib')
    local_fits = mirror.get(os.path.join(remote_plan.strip(os.path.basename(remote_plan)), exp_name))
    hdulist = fits.open(local_fits)
    fr, f, c, s = get_standards(plate=plates[0], mjd=mjds[0], fiber=1, band=band)
    wlen = 10**c[3].data[s[0]]
    flux = c[0].data[s[0]]
    return(wlen, flux)

# %%
wlen_b, flux_b = get_camera_data('blue')
wlen_r, flux_r = get_camera_data('red')

# %%
plt.plot(wlen_b, flux_b, '.')
plt.plot(wlen_r, flux_r, '.')

# %%
wlen_b[:3000]
# Out:
# array([ 2849.44867779,  2850.30093017,  2851.15339148, ...,  5969.39778876,
#         5970.52307382,  5971.64836578])

# %%
wlen_r
# Out:
# array([  5136.7598835 ,   5138.06138572,   5139.36301285, ...,
#         10990.07550894,  10991.48891472,  10992.90226159])

# %%
wlen_b_trim = wlen_b[60:]
flux_b_trim = flux_b[60:]
wlen_r_trim = wlen_r[60:]
wlen_b_trim = wlen_b_trim[:-80]
flux_b_trim = flux_b_trim[:-80]
wlen_r_trim = wlen_r_trim[:-80]
wlen_r_trim.shape
# Out:
# (3988,)

# %%
plt.plot(wlen_b_trim, flux_b_trim, '.')
plt.plot(wlen_b, flux_b, '.')

# %%
star_flux = Table([wlen, r_out, flux], names=('wavelength', 'wavelength_out', 'flux'))
star_flux.write('/Users/belaabolfathi/Documents/UCI/DESI/Specsim/star-sed.dat', format='ascii', overwrite=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-213-2f992ac574a8> in <module>()
# ----> 1 star_flux = Table([wlen, r_out, flux], names=('wavelength', 'wavelength_out', 'flux'))
#       2 star_flux.write('/Users/belaabolfathi/Documents/UCI/DESI/Specsim/star-sed.dat', format='ascii', overwrite=True)
#
# /Users/belaabolfathi/anaconda3/envs/bossdata/lib/python2.7/site-packages/astropy/table/table.pyc in __init__(self, data, masked, names, dtype, meta, copy, rows, copy_indices, **kwargs)
#     387
#     388         # Finally do the real initialization
# --> 389         init_func(data, names, dtype, n_cols, copy)
#     390
#     391         # Whatever happens above, the masked property should be set to a boolean
#
# ...

# %%
for i in range(len(s)):
    plt.plot(hdulist[2].data['MODELFLUX'][i], '.')

# %%
specsim.source.Source?

# %%
source = specsim.source.Source(name='star', type_name='table', wavelength_out=r_out*u.Angstrom, 
                      wavelength_in=wlen*u.Angstrom, flux_in=hdulist[2].data['MODELFLUX'][0]* u.erg / (u.Angstrom * u.s * u.cm ** 2), 
                      focal_xy=(79.956049*u.mm, 336.12358*u.mm), 
                      sky_position=(c[5].data['RA'][0]*u.deg, c[5].data['DEC'][0]*u.deg))

# %%
plt.plot(c[5].data['THROUGHPUT'], '.')
plt.ylim(np.percentile(c[5].data['THROUGHPUT'], (1, 99)))
# Out:
# (-76227.259999999995, 70260.08999999988)

# %%
wlen
# Out:
# array([  5136.7598835 ,   5138.06138572,   5139.36301285, ...,
#         10990.07550894,  10991.48891472,  10992.90226159])

# %% [markdown]
# ### Stellar models
# http://www.icg.port.ac.uk/~maraston/SSPn/SED/README_Mar05

# %%
path_to_sed = '/Users/belaabolfathi/Downloads/Sed_Mar05_SSP_Kroupa/'
path_to_csp = '/Users/belaabolfathi/Downloads/Sed_Mar05_CSP_Tau_Kroupa_Z02/'
sed001 = Table.read(path_to_sed + 'sed.krz002.bhb', format='ascii')
csp = Table.read(path_to_csp + 'csp_e0.10_z02_krou.sed_agb', format='ascii')

# %%
sed001[:5]
# Out:
# <Table length=5>
#   col1    col2    col3    col4
# float64 float64 float64 float64
# ------- ------- ------- -------
#    10.0     0.0    91.0     0.0
#    10.0     0.0    94.0     0.0
#    10.0     0.0    96.0     0.0
#    10.0     0.0    98.0     0.0
#    10.0     0.0   100.0     0.0

# %%
# !wc /Users/belaabolfathi/Downloads/Sed_Mar05_SSP_Kroupa/sed.krz002.bhb
# Out:
#     2442    9768  100122 /Users/belaabolfathi/Downloads/Sed_Mar05_SSP_Kroupa/sed.krz002.bhb

# %%
len(sed001)
# Out:
# 2442

# %%
plt.plot(sed001['col3'], '.')

# %%
plt.plot(sed001['col3'], sed001['col4'], '.')
plt.xlim(0,11000)
# Out:
# (0, 11000)

# %%
path_to_qso = '/Users/belaabolfathi/Data/desimodel/0.4.2/data/spectra/spec-ABmag22.0.dat'
qso_sed = Table.read(path_to_qso, format='ascii')

# %%
plt.plot(qso_sed['WAVELENGTH'], qso_sed['FLUX'], '.')
plt.show()

# %%
qso_sed[:3]
# Out:
# <Table length=3>
# WAVELENGTH   FLUX
#  float64   float64
# ---------- -------
#     2000.0  1.4093
#     3500.0  1.4093
#     3500.1  1.4092

# %%
plt.plot(csp['col2'], '.')

# %%
plt.plot(csp['col2'], csp['col3']/3.826e33, '.') #divide by 3.826e33 to get in terms of solar bolometric luminosity
plt.xlim(0,11000)
# Out:
# (0, 11000)

# %%
np.any(csp['col2'] == 2000.0)
# Out:
# False

# %%
np.max(qso_sed['WAVELENGTH'])
# Out:
# 11000.0

# %%
np.max(sed001['col3'])
# Out:
# 1600000.0

# %% [markdown]
# ### Chi squared fit of Kurucz profiles

# %%
km01 = Table.read('/Users/belaabolfathi/Desktop/kurucz/km01_7000.fits_g40_7120', format='ascii')
km15 = Table.read('/Users/belaabolfathi/Desktop/kurucz/km15_5250.fits_g20_5350', format='ascii')
km25 = Table.read('/Users/belaabolfathi/Desktop/kurucz/km25_5750.fits_g15_5910', format='ascii')

# %%
plt.scatter(km15['col1']*10, km15['col2'], s=1, alpha=0.3)
plt.xlim(0,2000)
plt.show()

# %%
plt.scatter(km25['col1'], km25['col2'], s=1, alpha=0.3)
plt.xlim(wlen[782],wlen[3305])
plt.show()

# %%
frame, flat, cframe, std = get_standards(plates[0], mjds[0], 4, 'blue')

# %%
for i in np.arange(800,len(flux)):
    if flux[i]==0:
        print(i)
        break
# Out:
# 3306

# %%
flux[782], flux[3305]
# Out:
# (10.062877, 19.232662)

# %%
flux = cframe[0].data[std[1]]
wlen = 10**cframe[3].data[std[1]]

plt.scatter(wlen, flux, s=1, alpha=0.3)
plt.xlim(wlen[782],wlen[3305])
plt.show()

# %%
(km15['col1'] == km01['col1']).all()
# Out:
# True

# %%
# kurucz profiles seem to be near zero in optical...

# %%
wlen[782],wlen[3305]
# Out:
# (3568.7605318981259, 6314.9355726159602)

# %%
for i in range(len(km15['col1'])):
    if (km15['col1'][i] > 3500) & (km15['col1'][i] < 3570):
        print(i)
# Out:
# 977
# 978
# 979

# %%
#interpolate kurucz profile on standard star grid for comparison?

# %%
np.interp(wlen[782:3305], km15['col1'], km15['col2']).shape
# Out:
# (2523,)

# %%
plt.scatter(wlen[782:3305], km15['col2'])
plt.scatter(km15['col1'], km15['col2'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-106-900687596dcc> in <module>()
# ----> 1 plt.scatter(wlen[782:3305], km15['col2'])
#       2 plt.scatter(km15['col1'], km15['col2'])
#       3 plt.show()
#
# /Users/belaabolfathi/anaconda3/envs/bossdata/lib/python2.7/site-packages/matplotlib/pyplot.pyc in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3433                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3434                          linewidths=linewidths, verts=verts,
# -> 3435                          edgecolors=edgecolors, data=data, **kwargs)
#    3436     finally:
#    3437         ax._hold = washold
#
# /Users/belaabolfathi/anaconda3/envs/bossdata/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
# ...

# %%
for the spectrophotometric standard stars is the best fit stellar model saved somewhere
